# %% [markdown]
# # Renewables Case Study: Conceptual Design Optimization

# %%
from dispatches.case_studies.renewables_case.RE_flowsheet import *

# %% [markdown]
# ## Creating the Superstructure Flowsheet with Wind, PEM Electrolyzer, Battery, H2 Tank and H2 Turbine Unit Models
#
# To create a design superstructure that contains all the technologies with which we are considering to hybridize the existing wind farm, there is the `create_model` function in `RE_flowsheet.py` which creates a Pyomo ConcreteModel for a single timestep and adds to it all the unit models, which are connected via Arcs.
#
# This flowsheet model can be created with any of the units models excluded: the simplest flowsheet contains only the wind plant, whereas the full flowsheet contains a PEM electrolzer, battery, hydrogen storage tank, and a hydrogen turbine arranged in the below configuration:
#
# ![re_superstructure_diagram.png](attachment:re_superstructure_diagram.png)
#
# In this graph, all the green and grey nodes represent IDAES unit models whereas the tan nodes are "markets" whose sales will be optimized in the later section on Objectives. The unit models have at least a size parameter that can be optimized. The rectangular nodes are unit models with no control variables, whereas the diamond nodes have operating variables whose values need to be decided. The oval node is a slack variable that allows the hydrogen flow into the turbine to be non-zero. There are 3 different ways to model the hydrogen tank, depending on which of the grey-bordered nodes are used; see the `add_h2_tank` section below.
#
# The `create_model` function's documentation can be found in-line with the code, and is shown below.

# %%
help(create_model)
# Out:
# Help on function create_model in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# create_model(wind_mw, pem_bar, batt_mw, tank_type, tank_length_m, turb_inlet_bar, wind_resource_config=None)
#     Creates a Flowsheet Pyomo model that puts together the Wind unit model with optional PEM, Hydrogen Tank, and Hydrogen Turbine unit models.
#
#     The input parameters determine the size of the technologies by fixing the appropriate variable. If the size parameter is None, the technology
#     will not be added.
#
#     The wind is first split among its output destinations: grid, battery and PEM with an ElectricalSplitter unit model.
#     After the PEM, a tank and turbine may be added. The `simple` tank model includes outlet ports for hydrogen flows to the turbine and the pipeline.
#     The `detailed` tank model uses a Splitter unit model to split the material and energy flows to the turbine and to hydrogen sales.
#
#     Args:
#         wind_mw: wind farm capacity
#         pem_bar: operating pressure of the PEM
#         batt_mw: nameplate power
#         tank_type: `simple`, `detailed`, or `detailed-valve`. See `add_h2_tank` for descriptions
#         tank_length_m: required if using `detailed` tank type, length of tank
#         turb_inlet_bar: operating inlet pressure of hydrogen to turbine
#         wind_resource_config: dictionary of Windpower Config keys (`resource_speed`, `resource_probability_density`) and ConfigValues. See `add_wind` for description

# %% [markdown]
# The `create_model` function uses individual functions to add each unit model separately. Each of these individual functions has input parameters of size and sometimes an operating condition such as pressure. The unit models added to the flowsheet are created with a fixed size and operating condition, and these constraints or fixed values will be relaxed in later steps to allow those variables to be optimized.
#
# The formulation of each of these models is described in the [DISPATCHES Documentation](https://dispatches.readthedocs.io/en/main/models/index.html)

# %%
# https://dispatches.readthedocs.io/en/main/models/renewables/wind_power.html
help(add_wind)
# Out:
# Help on function add_wind in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# add_wind(m, wind_mw, wind_resource_config=None)
#     Adds a wind unit to the flowsheet with a fixed system capacity and that uses resource data to determine the capacity factors
#
#     The resource data can be provided by configuring either `resource_speed` or `resource_probability_density`.
#     The `resource_speed` is a list of wind speeds (m/s) per timestep of the flowsheet.
#     The `resource_probability_density` is formatted as a 2d list where each row contains: (wind m/s, wind degrees from north clockwise, probability)
#     and the probabilities in all rows add up to 1.
#
#     Args:
#         m: existing ConcreteModel with a flowsheet `fs`
#         wind_mw: capacity of wind model to be fixed
#         wind_resource_config: dictionary of Windpower Config keys (`resource_speed`, `resource_probability_density`) and ConfigValues
#     Returns:
#         wind unit model in the flowsheet

# %%
# https://dispatches.readthedocs.io/en/main/models/renewables/pem_electrolyzer.html
help(add_pem)
# Out:
# Help on function add_pem in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# add_pem(m, outlet_pressure_bar)
#     Adds a PEM electrolyzer unit to the flowsheet with a fixed outlet pressure and conversion rate. The properties package is h2_ideal_vap.
#
#     The operating temperature and maximum pressure of the PEM are pulled from load_parameters.py
#
#     Args:
#         m: existing ConcreteModel with a flowsheet `fs`
#         outlet_pressure_bar: operating pressure of the PEM
#     Returns:
#         PEM electrolyzer unit model in the flowsheet
#         h2_ideal_vap property package in the flowsheet

# %%
# https://dispatches.readthedocs.io/en/main/models/renewables/battery.html
help(add_battery)
# Out:
# Help on function add_battery in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# add_battery(m, batt_mw)
#     Adds a Battery unit to the flowsheet with a fixed power and duration of 4 hours.
#
#     The charging and discharging efficiencies are set at 98%.
#
#     Args:
#         m: existing ConcreteModel with a flowsheet `fs`
#         batt_mw: nameplate power
#     Returns:
#         battery unit model in flowsheet

# %%
# Detailed Tank: https://dispatches.readthedocs.io/en/main/models/nuclear/hydrogen_tank.html
# Simplified Tank: 
help(add_h2_tank)
# Out:
# Help on function add_h2_tank in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# add_h2_tank(m, tank_type='simple', valve_outlet_bar=None, length_m=None)
#     Adds a Hydrogen Tank unit to the flowsheet, with 3 options for the model type: `simple`, `detailed` and `detailed-valve`.
#
#     For the `simple` type, the model is linear with no energy balances.
#     For the `detailed` type, the model is nonlinear with energy balances deactivated. The capacity of the tank is determined by its
#     geometry.
#     For the `detailed-valve` type, the `detailed` model is used, but with energy balances active and with a Valve unit.
#     The valve coefficient is pulled from load_parameters but needs to be be tuned per application.
#
#     Args:
#         m: existing ConcreteModel with a flowsheet `fs`
#         tank_type: `simple`, `detailed`, or `detailed-valve`
#         valve_outlet_bar: required if not using `simple` type, outlet pressure of the valve
#         length_m: required if using `detailed` type, length of tank
#     Returns:
#         tank (and valve) unit model(s) in flowsheet

# %%
# https://dispatches.readthedocs.io/en/main/models/nuclear/hydrogen_turbine.html
help(add_h2_turbine)
# Out:
# Help on function add_h2_turbine in module dispatches.case_studies.renewables_case.RE_flowsheet:
#
# add_h2_turbine(m, inlet_pres_bar)
#     Adds a hydrogen turbine unit to the flowsheet, using the h2_reaction_props property package.
#
#     A translator and mixer unit is added also. The mixer adds an `air_feed` and an `purchased_hydrogen_feed` to the `hydrogen_feed`.
#     The air_feed contains oxygen at a fixed ratio relative to the inlet hydrogen flow rate, `air_h2_ratio`, from load_parameters.
#     .The purchased_hydrogen_feed allows the turbine hydrogen inlet flow rate to be `h2_turb_min_flow`, which helps
#     with the model solve.
#
#     The `compressor_dp` is fixed from load_parameters, the compressor's isentropic efficiency is 0.86,
#     the stoichiometric conversion rate of hydrogen is 0.99, and the turbine's isentropic efficiency is 0.89.
#
#     The turbine's `electricity` is an Expression taking the difference between the turbine's and compressor's work.
#
#     Args:
#         m: existing ConcreteModel with a flowsheet `fs`
#         inlet_pres_bar: operating pressure of inlet air and hydrogen to the mixer
#     Returns:
#         tank (and valve, if applicable) unit model(s) in flowsheet

# %%
# Example flowsheet creation

wind_mw = 200
pem_bar = 1.01325
batt_mw = 50
tank_type = "simple"
h2_turb_bar = 24.7
tank_length_m = None
wind_resource_speed = { 'resource_speed': 10 }

m = create_model(wind_mw, pem_bar, batt_mw, tank_type, tank_length_m, h2_turb_bar, wind_resource_config=wind_resource_speed)

m.fs.battery.report()
# Out:
# ====================================================================================
# Unit : fs.battery                                                          Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                Inlet  Outlet   kWh
#     electricity               0.0000  0.0000      -
#     initial_state_of_charge        -       - 0.0000
#     initial_energy_throughput      -       - 0.0000
#     state_of_charge                -       - 0.0000
#     energy_throughput              -       - 0.0000
# ====================================================================================

# %% [markdown]
# ## Linking Flowsheets into a Dynamic Model with MultiPeriod Model
#
# The `MultiPeriodModel` class is used to link flowsheet models representing a single time point into sequential periods of time. Each time point is created by the `wind_battery_pem_tank_turb_model`, and dynamic state variables such as battery state of charge and hydrogen tank material (and energy) holdups are linked from one time period to the next with `wind_battery_pem_tank_turb_variable_pairs` and from the last to the first time period with `wind_battery_pem_tank_turb_periodic_variable_pairs`.
#
# The `wind_battery_pem_tank_turb_model` function creates the model using `create_model` with input parameter dictionary defining size and operating variables including the `wind_mw`, `pem_bar`, `tank_type`, `tank_size`, `pem_bar` and wind resource. The sizes are initial guesses for the optimal design and are unfixed during the optimization process, while the operating variables are fixed, currently.
#
# The operating PEM pressure used is 1.01325 bar and the operating pressure is 300 K. The produced hydrogen is at this state when it flows into the tank. The simple tank model doesn't track pressure and temperature and while the detailed tank model does, it does not model the energy required to compress the hydrogen. The hydrogen leaves the tank at 1.01325 bar and 300 K and enters the Mixer with an `air_feed` and a `purchased_hydrogen_feed`, this latter feed is simply to allow the minimum flow rate of hydrogen into the turbine, `h2_turb_min_flow`, to be greater than zero. The Air feed has a ratio of 10.76 to the hydrogen feed. The hydrogen turbine's change in pressure is 24.01 bar, and the outlet material is at 1.01325 bar.
#
# After the model is created, the model is initialized via `initialize_fs`. The initialization was designed to be applicable to all time points in the multiperiod model, and results in an initial state of the multiperiod model that is internally consistent, e.g. has little infeasibility. This initial state requires dynamic state variables are equal across time periods, and so during initialization, no energy flows through the battery and no hydrogen accumulates in the tank. Instead, all electricity from the wind flows to the grid.
#
# Finally, operating constraints and cost components are added to the model. The battery ramp rate is currently practically unconstrained, with `battery_ramp_rate` at 1e5 mWh/hr.

# %%
from dispatches.case_studies.renewables_case.wind_battery_PEM_tank_turbine_LMP import *

print("Cost Parameters:")
print(f"Wind Capital Cost\t\t\t{wind_cap_cost} $/kW")
print(f"Wind Fixed Operating Cost\t\t{wind_op_cost} $/kW-yr")
print(f"Battery Capital Cost\t\t\t{batt_cap_cost_kw} $/kW")
print(f"Battery Capital Cost\t\t\t{batt_cap_cost_kwh} $/kWh")
print(f"PEM Capital Cost\t\t\t{pem_cap_cost} $/kW")
print(f"PEM Fixed Operating Cost\t\t{pem_op_cost} $/kW-yr")
print(f"PEM Variable Operating Cost\t\t{pem_var_cost} $/kWh")
print(f"Tank Capital Cost\t\t\t{tank_cap_cost_per_kg} $/kg")
print(f"Tank Fixed Operating Cost\t\t{tank_op_cost} $/kg-yr")
print(f"Turbine Capital Cost\t\t\t{turbine_cap_cost} $/kW")
print(f"Turbine Fixed Operating Cost\t\t{turbine_op_cost} $/kW-yr")
print(f"Turbine Variable Operating Cost\t\t{turbine_var_cost} $/kWh")
# Out:
# Cost Parameters:
# Wind Capital Cost			1550 $/kW
# Wind Fixed Operating Cost		43 $/kW-yr
# Battery Capital Cost			634.88 $/kW
# Battery Capital Cost			171.71 $/kWh
# PEM Capital Cost			1600 $/kW
# PEM Fixed Operating Cost		47.9 $/kW-yr
# PEM Variable Operating Cost		0.0013 $/kWh
# Tank Capital Cost			971.5 $/kg
# Tank Fixed Operating Cost		165.155 $/kg-yr
# Turbine Capital Cost			1000 $/kW
# Turbine Fixed Operating Cost		11.65 $/kW-yr
# Turbine Variable Operating Cost		0.0042699999999999995 $/kWh

# %%
prices_used[prices_used > 200] = 200

input_params = {
    "wind_mw": wind_mw,
    "wind_mw_ub": wind_mw_ub,
    "batt_mw": fixed_batt_mw,
    "batt_hr": 4,
    "pem_mw": fixed_pem_mw,
    "pem_bar": pem_bar,
    "pem_temp": pem_temp,
    "tank_size": fixed_tank_kg,
    "tank_type": "simple",
    "turb_mw": turb_p_mw,

    "wind_resource": wind_capacity_factors,
    "h2_price_per_kg": h2_price_per_kg,
    "LMPs": prices_used,

    "design_opt": True,
    "extant_wind": True,

    "opt_mode": "profit",

    "wind_cap_cost": wind_cap_cost,
    "wind_op_cost": wind_op_cost,
    "batt_cap_cost_kw": batt_cap_cost_kw,
    "batt_cap_cost_kwh": batt_cap_cost_kwh,
    "batt_rep_cost_kwh": batt_rep_cost_kwh,
    "pem_cap_cost": pem_cap_cost,
    "pem_op_cost": pem_op_cost,
    "pem_var_cost": pem_var_cost,
    "tank_cap_cost_per_kg": tank_cap_cost_per_kg,
    "tank_op_cost":tank_op_cost,
    "turbine_cap_cost": turbine_cap_cost,
    "turbine_op_cost": turbine_op_cost,
    "turbine_var_cost": turbine_var_cost
}
                 
m = wind_battery_pem_tank_turb_model(wind_resource_speed, input_params, verbose=False)

# Display the current initialized state of the flowsheet

m.fs.windpower.display()
m.fs.splitter.report()
m.fs.battery.report()
m.fs.pem.report()
m.fs.h2_tank.display()
m.fs.h2_turbine.report()
# Out:
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# Block fs.windpower
#
#   Variables:
#     system_capacity : Rated system capacity of wind farm
#         Size=1, Index=None, Units=kW
#         Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#         None :     0 : 200000.0 :  None :  True :  True : NonNegativeReals
#     electricity : Electricity production
#         Size=1, Index=fs._time, Units=kW
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 120333.55002771995 :  None : False :  True : NonNegativeReals
#
#   Objectives:
#     None
#
#   Constraints:
#     elec_from_capacity_factor : Size=1
#         Key : Lower : Body : Upper
#         0.0 :  None :  0.0 :   0.0
#
# ====================================================================================
# Unit : fs.splitter                                                         Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                    Inlet     Outlet
#     electricity 1.2033e+05          -
#     grid                 - 1.2033e+05
#     pem                  -     0.0000
#     battery              -     0.0000
# ====================================================================================
#
# ====================================================================================
# Unit : fs.battery                                                          Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                Inlet  Outlet     kWh
#     electricity               0.0000  0.0000          -
#     initial_state_of_charge        -       -     0.0000
#     initial_energy_throughput      -       -     0.0000
#     state_of_charge                -       - 4.2352e-22
#     energy_throughput              -       - 4.2352e-22
# ====================================================================================
#
# ====================================================================================
# Unit : fs.pem                                                              Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                  Inlet     Units        Outlet
#     Total Molar Flowrate            -   mole / second     0.0000
#     Total Mole Fraction hydrogen    -   dimensionless     1.0000
#     Temperature                     -          kelvin     300.00
#     Pressure                        -          pascal 1.0132e+05
#     Electricity                     0               -          -
# ====================================================================================
# Block fs.h2_tank
#
#   Variables:
#     _flow_mol_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_in[...].component('flow_mol')
#         Key : Lower : Value : Upper  : Fixed : Stale : Domain
#         0.0 :     0 :   0.0 : 100000 : False :  True : NonNegativeReals
#     _mole_frac_comp_inlet_ref : Size=1, Index=fs.h2_tank._mole_frac_comp_inlet_ref_index, ReferenceTo=fs.h2_tank.properties_in[...].component('mole_frac_comp')[...]
#         Key               : Lower : Value : Upper : Fixed : Stale : Domain
#         (0.0, 'hydrogen') : 1e-20 :   1.0 : 1.001 : False :  True :  Reals
#     _temperature_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_in[...].component('temperature')
#         Key : Lower  : Value : Upper : Fixed : Stale : Domain
#         0.0 : 273.15 :   300 :  1000 : False :  True : NonNegativeReals
#     _pressure_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_in[...].component('pressure')
#         Key : Lower   : Value    : Upper     : Fixed : Stale : Domain
#         0.0 : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#     _flow_mol_outlet_to_turbine_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_turbine[...].component('flow_mol')
#         Key : Lower : Value : Upper  : Fixed : Stale : Domain
#         0.0 :     0 :   0.0 : 100000 : False :  True : NonNegativeReals
#     _mole_frac_comp_outlet_to_turbine_ref : Size=1, Index=fs.h2_tank._mole_frac_comp_outlet_to_turbine_ref_index, ReferenceTo=fs.h2_tank.properties_out_turbine[...].component('mole_frac_comp')[...]
#         Key               : Lower : Value : Upper : Fixed : Stale : Domain
#         (0.0, 'hydrogen') : 1e-20 :     1 : 1.001 :  True :  True :  Reals
#     _temperature_outlet_to_turbine_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_turbine[...].component('temperature')
#         Key : Lower  : Value : Upper : Fixed : Stale : Domain
#         0.0 : 273.15 : 300.0 :  1000 : False :  True : NonNegativeReals
#     _pressure_outlet_to_turbine_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_turbine[...].component('pressure')
#         Key : Lower   : Value    : Upper     : Fixed : Stale : Domain
#         0.0 : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#     _flow_mol_outlet_to_pipeline_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_pipeline[...].component('flow_mol')
#         Key : Lower : Value : Upper  : Fixed : Stale : Domain
#         0.0 :     0 :     0 : 100000 : False :  True : NonNegativeReals
#     _mole_frac_comp_outlet_to_pipeline_ref : Size=1, Index=fs.h2_tank._mole_frac_comp_outlet_to_pipeline_ref_index, ReferenceTo=fs.h2_tank.properties_out_pipeline[...].component('mole_frac_comp')[...]
#         Key               : Lower : Value : Upper : Fixed : Stale : Domain
#         (0.0, 'hydrogen') : 1e-20 :     1 : 1.001 :  True :  True :  Reals
#     _temperature_outlet_to_pipeline_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_pipeline[...].component('temperature')
#         Key : Lower  : Value : Upper : Fixed : Stale : Domain
#         0.0 : 273.15 : 300.0 :  1000 : False :  True : NonNegativeReals
#     _pressure_outlet_to_pipeline_ref : Size=1, Index=fs._time, ReferenceTo=fs.h2_tank.properties_out_pipeline[...].component('pressure')
#         Key : Lower   : Value    : Upper     : Fixed : Stale : Domain
#         0.0 : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#     tank_holdup_previous : Size=1, Index=fs._time, Units=mol
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 :     0 :  None : False :  True : NonNegativeReals
#     tank_holdup : Size=1, Index=fs._time, Units=mol
#         Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 4.235164736271502e-22 :  None : False :  True : NonNegativeReals
#     dt : Size=1, Index=fs._time, Units=s
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 :  3600 :  None :  True :  True : NonNegativeReals
#
#   Objectives:
#     None
#
#   Constraints:
#     eq_temperature_1 : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     eq_temperature_2 : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     eq_pressure_1 : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     eq_pressure_2 : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     tank_material_balance : Size=1
#         Key : Lower : Body                  : Upper
#         0.0 :   0.0 : 4.235164736271502e-22 :   0.0
#
#   Blocks:
#     Block fs.h2_tank.properties_in[0.0]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value : Upper  : Fixed : Stale : Domain
#             None :     0 :   0.0 : 100000 : False :  True : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=1, Index=fs.h2ideal_props.component_list, Units=dimensionless
#             Key      : Lower : Value : Upper : Fixed : Stale : Domain
#             hydrogen : 1e-20 :   1.0 : 1.001 : False :  True :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower   : Value    : Upper     : Fixed : Stale : Domain
#             None : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#             None : 273.15 :   300 :  1000 : False :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=mol/s
#             Key : Lower : Value                 : Upper  : Fixed : Stale : Domain
#             Vap :     0 : 4.235164736271502e-22 : 100000 : False :  True : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=1, Index=fs.h2ideal_props._phase_component_set, Units=dimensionless
#             Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#             ('Vap', 'hydrogen') : 1e-20 :   1.0 : 1.001 : False :  True :  Reals
#         phase_frac : Phase fractions
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=dimensionless
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             Vap :     0 :   1.0 :  None : False :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         total_flow_balance : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : -4.235164736271502e-22 :   0.0
#         component_flow_balances : Size=1
#             Key      : Lower : Body : Upper
#             hydrogen :   0.0 :  0.0 :   0.0
#         phase_fraction_constraint : Size=1
#             Key : Lower : Body : Upper
#             Vap :   1.0 :  1.0 :   1.0
#     Block fs.h2_tank.properties_out_pipeline[0.0]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value : Upper  : Fixed : Stale : Domain
#             None :     0 :     0 : 100000 : False :  True : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=1, Index=fs.h2ideal_props.component_list, Units=dimensionless
#             Key      : Lower : Value : Upper : Fixed : Stale : Domain
#             hydrogen : 1e-20 :     1 : 1.001 :  True :  True :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower   : Value    : Upper     : Fixed : Stale : Domain
#             None : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#             None : 273.15 : 300.0 :  1000 : False :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=mol/s
#             Key : Lower : Value                 : Upper  : Fixed : Stale : Domain
#             Vap :     0 : 4.235164736271502e-22 : 100000 : False :  True : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=1, Index=fs.h2ideal_props._phase_component_set, Units=dimensionless
#             Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#             ('Vap', 'hydrogen') : 1e-20 :   1.0 : 1.001 : False :  True :  Reals
#         phase_frac : Phase fractions
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=dimensionless
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             Vap :     0 :   1.0 :  None : False :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         total_flow_balance : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : -4.235164736271502e-22 :   0.0
#         component_flow_balances : Size=1
#             Key      : Lower : Body : Upper
#             hydrogen :   0.0 :  0.0 :   0.0
#         phase_fraction_constraint : Size=1
#             Key : Lower : Body : Upper
#             Vap :   1.0 :  1.0 :   1.0
#     Block fs.h2_tank.properties_out_turbine[0.0]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value : Upper  : Fixed : Stale : Domain
#             None :     0 :   0.0 : 100000 : False :  True : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=1, Index=fs.h2ideal_props.component_list, Units=dimensionless
#             Key      : Lower : Value : Upper : Fixed : Stale : Domain
#             hydrogen : 1e-20 :     1 : 1.001 :  True :  True :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower   : Value    : Upper     : Fixed : Stale : Domain
#             None : 50000.0 : 101325.0 : 1000000.0 : False :  True : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#             None : 273.15 : 300.0 :  1000 : False :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=mol/s
#             Key : Lower : Value                 : Upper  : Fixed : Stale : Domain
#             Vap :     0 : 4.235164736271502e-22 : 100000 : False :  True : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=1, Index=fs.h2ideal_props._phase_component_set, Units=dimensionless
#             Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#             ('Vap', 'hydrogen') : 1e-20 :   1.0 : 1.001 : False :  True :  Reals
#         phase_frac : Phase fractions
#             Size=1, Index=fs.h2ideal_props.phase_list, Units=dimensionless
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             Vap :     0 :   1.0 :  None : False :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         total_flow_balance : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : -4.235164736271502e-22 :   0.0
#         component_flow_balances : Size=1
#             Key      : Lower : Body : Upper
#             hydrogen :   0.0 :  0.0 :   0.0
#         phase_fraction_constraint : Size=1
#             Key : Lower : Body : Upper
#             Vap :   1.0 :  1.0 :   1.0
#
# ====================================================================================
# Unit : fs.h2_turbine.compressor                                            Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.76000 : dimensionless :  True : (None, None)
#           Mechanical Work :     131.70 :          watt : False : (None, None)
#           Pressure Change : 1.0000e+06 :        pascal :  True : (None, None)
#            Pressure Ratio :     11.000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second   0.011762   0.011762
#     Total Mole Fraction hydrogen  dimensionless   0.085333   0.085333
#     Total Mole Fraction nitrogen  dimensionless    0.70187    0.70187
#     Total Mole Fraction oxygen    dimensionless    0.18791    0.18791
#     Total Mole Fraction water     dimensionless   0.021958   0.021958
#     Total Mole Fraction argon     dimensionless  0.0029351  0.0029351
#     Temperature                          kelvin     300.00     672.10
#     Pressure                             pascal 1.0000e+05 1.1000e+06
# ====================================================================================
#
# ====================================================================================
# Unit : fs.h2_turbine.stoic_reactor                                         Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#     Reaction Extent [R1] : 0.00035128 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second   0.011762   0.011410
#     Total Mole Fraction hydrogen  dimensionless   0.085333   0.026388
#     Total Mole Fraction nitrogen  dimensionless    0.70187    0.72347
#     Total Mole Fraction oxygen    dimensionless    0.18791    0.16291
#     Total Mole Fraction water     dimensionless   0.021958   0.084206
#     Total Mole Fraction argon     dimensionless  0.0029351  0.0030255
#     Temperature                          kelvin     672.10     1144.0
#     Pressure                             pascal 1.1000e+06 1.1000e+06
# ====================================================================================
#
# ====================================================================================
# Unit : fs.h2_turbine.turbine                                               Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.79000 : dimensionless :  True : (None, None)
#           Mechanical Work :     -154.26 :          watt : False : (None, None)
#           Pressure Change : -1.0000e+06 :        pascal :  True : (None, None)
#            Pressure Ratio :    0.090909 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second   0.011410   0.011410
#     Total Mole Fraction hydrogen  dimensionless   0.026388   0.026388
#     Total Mole Fraction nitrogen  dimensionless    0.72347    0.72347
#     Total Mole Fraction oxygen    dimensionless    0.16291    0.16291
#     Total Mole Fraction water     dimensionless   0.084206   0.084206
#     Total Mole Fraction argon     dimensionless  0.0030255  0.0030255
#     Temperature                          kelvin     1144.0     733.29
#     Pressure                             pascal 1.1000e+06 1.0000e+05
# ====================================================================================

# %% [markdown]
# The Multiperiod model is constructed for 7 time points as shown below:

# %%
mp_model = MultiPeriodModel(n_time_points=7,
                            process_model_func=partial(wind_battery_pem_tank_turb_mp_block, input_params=input_params, verbose=False),
                            linking_variable_func=partial(wind_battery_pem_tank_turb_variable_pairs, tank_type=tank_type),
                            periodic_variable_func=partial(wind_battery_pem_tank_turb_periodic_variable_pairs, tank_type=tank_type))
mp_model.build_multi_period_model(input_params['wind_resource'])
# Out:
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# 2023-04-14 09:52:00 [WARNING] idaes.apps.grid_integration.multiperiod.multiperiod: Initialization function is not provided. Returning the multiperiod model without initialization.
# 2023-04-14 09:52:00 [WARNING] idaes.apps.grid_integration.multiperiod.multiperiod: unfix_dof function is not provided. Returning the model without unfixing degrees of freedom

# %% [markdown]
# ## Optimizing for Net Present Value
#
# For the design optimization, the "historical" Locational Marginal Price for the Day-Ahead market for the RTS-GMLC is used as the price signal and the hybrid system is operated as a "price taker". The price taker assumption is that the LMPs of the electricity market will stay steady regardless of the energy production of the system. This assumption will be removed in the double-loop simulation below, in which the energy system is co-simulated within the production cost model, and the actual dispatch and revenue of the system can be evalluated.
#
# In the following example, we run a design optimization with an existing 200 MW wind farm, with a hydrogen price of $2.0/kg, using the first 7 days of Day Ahead Market prices. These prices are results from a full year simulation of the RTS-GMLC with Prescient.
#
# The function `wind_battery_pem_tank_turb_optimize` creates the MultiPeriodModel and adds the size and operating constraints in addition to the Net Present Value Objective. The NPV is a function of the capital costs, the electricity market profit, the hydrogen market profit, and the capital recovery factor. The operating decisions and state evolution of the unit models and the flowsheet as a whole form the constraints of the Non-linear Program.
#
# $$
# \begin{align}
# \max_{S_{i \in I}} \:
#     & -\Sigma_{i \in I}C_{i} & & \\
#     & + \big[ \Sigma_t  P_{lmp, t} * (E_{splitter, t} + E_{batt, t} +E_{turb, t}) - (O_{wind, t} + O_{pem, t} + O_{tank, t} + O_{turb, t}) \\
#     & + \big( P_{h2, t} * (F_{sold, t} - F_{purchased, t}) \big) \big] \\
#     & * 52.143 / n_{weeks} / CRF \\
#     \\
# st \;\;
#     & g_n(S, P, E, F) \leq 0 \\
#     & h_m(S, P, E, F, O) = 0
# \end{align}
# $$
#
# $I = [wind, batt, pem, tank, turb]$ is the set of technologies
#
# $S_i$ is the size of technology $i$
#
# $C_{i}$ is the total installed cost of a technology
#
# $P_{lmp, t}$ and $P_{h2, t}$ are market prices at time $t$
#
# $O_{i, t}$ is the total operating cost of a technology for a single time step
#
# $F_{sold, t}$ and $F_{purchased, t}$ are flows of hydrogen to and from the market
#
# $n_{weeks}$ is the number of weeks in the MultiPeriod Model.
#
#
# There are two settings for the optimization:
#
# `design_opt`: If true, the size variables are free to be optimized, otherwise the sizes are fixed at the initial guess sizes.
#
# `extant_wind`: If true, assume the wind plant already exists, so fix the wind size to the initial size and do not add wind capital cost to NPV.

# %%
design_res = wind_battery_pem_tank_turb_optimize(n_time_points=7 * 24, input_params=input_params, verbose=False, plot=True)
# Out:
# Help on function wind_battery_pem_tank_turb_optimize in module dispatches.case_studies.renewables_case.wind_battery_PEM_tank_turbine_LMP:
#
# wind_battery_pem_tank_turb_optimize(n_time_points, input_params, verbose=False, plot=False)
#     The main function for optimizing the flowsheet's design and operating variables for Net Present Value.
#
#     Creates the MultiPeriodModel and adds the size and operating constraints in addition to the Net Present Value Objective.
#     The NPV is a function of the capital costs, the electricity market profit, the hydrogen market profit, and the capital recovery factor.
#     The operating decisions and state evolution of the unit models and the flowsheet as a whole form the constraints of the Non-linear Program.
#
#     Required input parameters include:
#         `wind_mw`: initial guess of the wind size
#         `wind_mw_ub`: upper bound of wind size
#         `batt_mw`: initial guess of the battery size
#         `pem_mw`: initial guess of the pem size
#         `pem_bar`: operating pressure
#         `pem_temp`: operating temperature [K]
#         `tank_size`: initial guess of the tank_size [kg H2]
#         `tank_type`: "simple", "detailed" or "detailed-valve"
#         `turb_mw`: intial guess of the turbine size
#         `wind_resource`: dictionary of wind resource configs for each time point
#         `h2_price_per_kg`: market price of hydrogen
#         `LMPs`: LMPs for each time point
#         `design_opt`: true to optimize design, else sizes are fixed at initial guess sizes
#         `extant_wind`: if true, fix wind size to initial size and do not add wind capital cost to NPV
#
#     Args:
#         n_time_points: number of periods in MultiPeriod model
#         input_params:
#         verbose: print all logging and outputs from unit models, initialization, solvers, etc
#         plot: plot the operating variables time series
#
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'fs.splitter.scaling_factor' that
#     contains 6 component keys that are not exported as part of the NL file.
#     Skipping.
# 2023-04-14 09:52:25 [WARNING] idaes.apps.grid_integration.multiperiod.multiperiod: Initialization function is not provided. Returning the multiperiod model without initialization.
# 2023-04-14 09:52:25 [WARNING] idaes.apps.grid_integration.multiperiod.multiperiod: unfix_dof function is not provided. Returning the model without unfixing degrees of freedom
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.turbi
#     ne.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_in[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.compr
#     essor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.compr
#     essor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.h2_turbine.compr
#     essor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.h2_turbine.compressor.control_volume.scaling_facto
#     r' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[167].process.fs.mixer.purchased_
#     hydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor'
#     that contains 7 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.translator.properties_out[0.0].scaling_factor'
#     that contains 10 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_facto
#     r' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.pem.outlet_state[0.0].scaling_factor' that
#     contains 3 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[167].process.fs.windpower.scaling_factor' that contains 1
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.turbi
#     ne.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_in[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.compr
#     essor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.compr
#     essor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.h2_turbine.compr
#     essor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.h2_turbine.compressor.control_volume.scaling_facto
#     r' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[166].process.fs.mixer.purchased_
#     hydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor'
#     that contains 7 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.translator.properties_out[0.0].scaling_factor'
#     that contains 10 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_facto
#     r' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.pem.outlet_state[0.0].scaling_factor' that
#     contains 3 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[166].process.fs.windpower.scaling_factor' that contains 1
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.turbi
#     ne.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_in[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.compr
#     essor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.compr
#     essor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.h2_turbine.compr
#     essor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.h2_turbine.compressor.control_volume.scaling_facto
#     r' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[165].process.fs.mixer.purchased_
#     hydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor'
#     that contains 7 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.translator.properties_out[0.0].scaling_factor'
#     that contains 10 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_facto
#     r' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.pem.outlet_state[0.0].scaling_factor' that
#     contains 3 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[165].process.fs.windpower.scaling_factor' that contains 1
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.turbi
#     ne.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.stoic
#     _reactor.control_volume.properties_in[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.compr
#     essor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.compr
#     essor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.h2_turbine.compr
#     essor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.h2_turbine.compressor.control_volume.scaling_facto
#     r' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[164].process.fs.mixer.purchased_
#     hydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor'
#     that contains 7 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.translator.properties_out[0.0].scaling_factor'
#     that contains 10 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_facto
#     r' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.pem.outlet_state[0.0].scaling_factor' that
#     contains 3 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[164].process.fs.windpower.scaling_factor' that contains 1
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[163].process.fs.h2_turbine.turbi
#     ne.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[163].process.fs.h2_turbine.turbi
#     ne.control_volume.properties_out[0.0].scaling_factor' that contains 7
# ...
#     ssor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.h2_turbine.compressor.control_volume.scaling_factor
#     ' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[28].process.fs.mixer.purchased_h
#     ydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.translator.properties_out[0.0].scaling_factor' that
#     contains 10 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor'
#     that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.pem.outlet_state[0.0].scaling_factor' that contains
#     3 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[28].process.fs.windpower.scaling_factor' that contains 1 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.turbin
#     e.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.turbin
#     e.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.turbin
#     e.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_in[0.0].scaling_factor' that contains 12
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.compre
#     ssor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.h2_turbine.compressor.control_volume.scaling_factor
#     ' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[27].process.fs.mixer.purchased_h
#     ydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.translator.properties_out[0.0].scaling_factor' that
#     contains 10 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor'
#     that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.pem.outlet_state[0.0].scaling_factor' that contains
#     3 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[27].process.fs.windpower.scaling_factor' that contains 1 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.turbin
#     e.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.turbin
#     e.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.turbin
#     e.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_in[0.0].scaling_factor' that contains 12
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.compre
#     ssor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.h2_turbine.compressor.control_volume.scaling_factor
#     ' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[26].process.fs.mixer.purchased_h
#     ydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.translator.properties_out[0.0].scaling_factor' that
#     contains 10 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor'
#     that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.h2_tank.properties_out_pipeline[0.0].scaling_factor
#     ' that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.h2_tank.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.pem.outlet_state[0.0].scaling_factor' that contains
#     3 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[26].process.fs.windpower.scaling_factor' that contains 1 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.turbin
#     e.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.turbin
#     e.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.turbin
#     e.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.h2_turbine.turbine.control_volume.scaling_factor'
#     that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_out[0.0].scaling_factor' that contains
#     12 component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.stoic_
#     reactor.control_volume.properties_in[0.0].scaling_factor' that contains 12
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.compre
#     ssor.properties_isentropic[0.0].scaling_factor' that contains 8 component
#     keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_out[0.0].scaling_factor' that contains 7
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.h2_turbine.compre
#     ssor.control_volume.properties_in[0.0].scaling_factor' that contains 8
#     component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.h2_turbine.compressor.control_volume.scaling_factor
#     ' that contains 1 component keys that are not exported as part of the NL
#     file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.mixer.mixed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix 'blocks[25].process.fs.mixer.purchased_h
#     ydrogen_feed_state[0.0].scaling_factor' that contains 11 component keys
#     that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.mixer.hydrogen_feed_state[0.0].scaling_factor' that
#     contains 7 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.mixer.air_feed_state[0.0].scaling_factor' that
#     contains 14 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.translator.properties_out[0.0].scaling_factor' that
#     contains 10 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.translator.properties_in[0.0].scaling_factor' that
#     contains 1 component keys that are not exported as part of the NL file.
#     Skipping.
# WARNING: model contains export suffix
#     'blocks[25].process.fs.h2_tank.properties_out_turbine[0.0].scaling_factor'
#     that contains 2 component keys that are not exported as part of the NL
#     file.  Skipping.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'wind_mw': 300.19251677985204, 'batt_mw': 0.0005196752925927142, 'batt_mwh': 0.0020586073377619253, 'pem_mw': 152.02278773291792, 'tank_kgH2': 0.036655059241975374, 'turb_mw': 0.00024036873075117764, 'avg_turb_kWh_per_kgH2': 24.17521746418069, 'annual_rev_h2': 36404718.3883275, 'annual_rev_E': -13290641.181096645, 'NPV': 113059730.18776482}

# %% [markdown]
# ## Interpreting Annual Conceptual Design Results
#
# The results show that for an existing wind plant of 200 MW, the best NPV is \\$319B from a 314 MW 4-hr battery (the 0.02 MW PEM electrolyzer and 1.52 kgH2 tank should both be considered as 0). The timeseries on the first plot shows two x-axes: the plant's powerflows in kW on the left with colored lines and the LMP signal in \\$/MWh on the right in the black line. The second plot shows the hydrogen flows, and in this design, since the PEM is nearly 0, there is minimal activity with hydrogen. The third plot shows the hourly and cumulative revenues for the electricity and hydrogen markets.
#
# The optimal design gives a very large battery size, and there are several reasons for this result. The first is that the pricetaker perspective does not account for the depth of the energy market at any time point, and whether prices would be supressed (or increased) by all the battery discharging (or charging), nor whether the battery would even be scheduled to dispatch at its desired times. The second is that this analysis is using only the first week of the year, during which there is high wind production relative to the rest of the year, and extrapolating those conditions to a 30-year project lifetime. Using a full year's data will increase the representativeness of the power and price profiles. Finally, the result is highly dependent on the cost and price assumptions, the most uncertain of them being the LMP time series but also the price of hydrogen has a large impact on the relative benefits of electricity vs hydrogen production.
#
# The design optimization was simulated across a few hydrogen prices and time horizons, and the results are shown and plotted below. While the table does not have results for the full factorial design of the 3 hydrogen prices and the 6 time horizons, it does give an idea of the variance of the optimal design.

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

res_df = pd.read_csv("ConceptualDesignResults.csv", index_col="index")
res_df['Max LMP'] = res_df['Max LMP'].astype(int)
# res_df.query("h2_price_per_kg == 3 and Market == 'DA' and build_add_wind == 0")
res_df
# Out:
#             wind_mw       batt_mw  pem_mw      turb_mw  h2_price_per_kg  \
# index
# 0        847.000000      0.000000     0.4     0.000000             2.00
# 1      10000.000000  95000.000000  1000.0  3601.687828             2.25
# 2        847.000000  16314.579742     0.0     0.000000             3.00
# 3        847.000000  17759.487130     0.0     0.000000             2.75
# 4        847.000000      0.000000   207.3     0.000000             3.00
# ...             ...           ...     ...          ...              ...
# 95       847.000000      0.000000     0.4     0.000000             2.00
# 96         0.000000      0.000000     0.0     0.000000             2.25
# 97       847.000000    896.272750     0.0     0.000000             2.00
# 98         0.000000      0.000000     0.0     0.000000             2.25
# 99      1252.493805  95000.000000     0.0     0.000000             2.25
#
#        build_add_wind    batt_hr        batt_mwh   tank_tonH2  annual_rev_h2  \
# index
# 0                   0   0.000000        0.000000     0.000000   1.128562e+05
# 1                   1  10.526316  1000000.000000  4901.669083   3.871505e+07
# 2                   0   9.749426   159057.787500     0.000000   0.000000e+00
# 3                   0   8.099797   143848.236042     0.000000   0.000000e+00
# 4                   0   0.000000        0.000000     0.000000   5.255999e+07
# ...               ...        ...             ...          ...            ...
# 95                  0   0.000000        0.000000     0.000000   1.128562e+05
# 96                  1   0.000000        0.000000     0.000000   0.000000e+00
# 97                  0   1.052632      943.445000     0.000000   0.000000e+00
# 98                  1   0.000000        0.000000     0.000000   0.000000e+00
# 99                  1   1.052632   100000.000000     0.000000   0.000000e+00
#
#        annual_revenue  annual_rev_E Market  Max LMP  Wind Design   NPV [$Bil]
# index
# 0       -2.123394e+07  1.513841e+07     DA      200            0    -1.639908
# 1        1.454529e+11  1.470738e+11   Both     7550            1  1978.922685
# 2        1.871906e+10  1.880682e+10   Both    10000            0   248.775430
# 3        1.403382e+10  1.410875e+10   Both     7550            0   178.446020
# 4        1.122129e+07  6.139243e+06     DA     2650            0    -1.472031
# ...               ...           ...    ...      ...          ...          ...
# 95      -1.883420e+07  1.754472e+07     DA     2650            0    -1.603018
# 96       0.000000e+00  0.000000e+00   Both      200            1     0.000000
# 97       3.551932e+07  7.213722e+07     DA     7550            0    -1.497856
# 98       0.000000e+00  0.000000e+00     DA     2650            1     0.000000
# 99       5.770403e+09  5.840201e+09     DA    10000            1     9.279275
#
# [100 rows x 16 columns]

# %%
colormaps = [sns.color_palette("Purples", as_cmap=True), # NPV
             sns.color_palette("Greys", as_cmap=True), # Wind
             sns.color_palette("Blues", as_cmap=True), # Battery
             sns.color_palette("Greens", as_cmap=True), # PEM
             sns.color_palette("YlOrBr", as_cmap=True), # Turbine
             ]

def plot_results(results, title):
    fig, axs = plt.subplots(1, 5 if 'wind_mw' in results.columns else 4, figsize=(5 * (len(results.columns) - 2), 4.5), sharex=True, sharey=True)
    sns.heatmap(results.pivot_table(index='Max LMP', 
                                    columns="h2_price_per_kg", 
                                    values='NPV [$Bil]',
                                    aggfunc='mean'), annot=True, fmt=".1f", ax=axs[0],
                                    cbar=False, cmap=colormaps[0]
                                    )
    axs[0].set_title("NPV [$Bil]")
    axs[0].set_xlabel("Hydrogen Price [$/kg]")
    axs[0].set_ylabel("Max LMP [$/MWh]")

    i = 1
    if 'wind_mw' in results.columns:
        sns.heatmap(results.pivot_table(index='Max LMP', 
                                        columns="h2_price_per_kg", 
                                        values='wind_mw',
                                        aggfunc='mean'), annot=True, fmt=".0f", ax=axs[i],
                                        cbar=False, cmap=colormaps[1]
                                        )
        axs[i].set_title("Wind MW")
        axs[i].set_xlabel("Hydrogen Price [$/kg]")
        axs[i].set_ylabel("Max LMP [$/MWh]")
        i += 1

    sns.heatmap(results.pivot_table(index='Max LMP', 
                                    columns="h2_price_per_kg", 
                                    values='batt_mw',
                                    aggfunc='mean'), annot=True, fmt=".0f", ax=axs[i],
                                    cbar=False, cmap=colormaps[2]
                                    )
    axs[i].set_title("Battery MW")
    axs[i].set_xlabel("Hydrogen Price [$/kg]")
    axs[i].set_ylabel("Max LMP [$/MWh]")
    i += 1

    sns.heatmap(results.pivot_table(index='Max LMP', 
                                    columns="h2_price_per_kg", 
                                    values='pem_mw',
                                    aggfunc='mean'), annot=True, fmt=".0f", ax=axs[i],
                                    cbar=False, cmap=colormaps[3]
                                    )
    axs[i].set_title("PEM MW")
    axs[i].set_xlabel("Hydrogen Price [$/kg]")
    axs[i].set_ylabel("Max LMP [$/MWh]")
    i += 1

    sns.heatmap(results.pivot_table(index='Max LMP', 
                                    columns="h2_price_per_kg", 
                                    values='turb_mw',
                                    aggfunc='mean'), annot=True, fmt=".0f", ax=axs[i],
                                    cbar=False, cmap=colormaps[4]
                                    )
    axs[i].set_title("Hydrogen Turbine MW")
    axs[i].set_xlabel("Hydrogen Price [$/kg]")
    axs[i].set_ylabel("Max LMP [$/MWh]")
    i += 1

    axs[0].invert_yaxis()
    plt.suptitle(title)

# %%
results = res_df.query("Market == 'DA' and build_add_wind == 0")[['Max LMP', 'h2_price_per_kg', 'NPV [$Bil]', 'batt_mw', 'pem_mw', 'turb_mw']]
plot_results(results, "Fixed Wind Design for DA Market")

# %%
results = res_df.query("Market == 'Both' and build_add_wind == 0")[['Max LMP', 'h2_price_per_kg', 'NPV [$Bil]', 'batt_mw', 'pem_mw', 'turb_mw']]
plot_results(results, "Fixed Wind Design for DA+RT Market")

# %%
results = res_df.query("Market == 'DA' and build_add_wind == 1")[['Max LMP', 'h2_price_per_kg', 'NPV [$Bil]', 'wind_mw', 'batt_mw', 'pem_mw', 'turb_mw']]
plot_results(results, "Variable Wind Design for DA Market")

# %%
results = res_df.query("Market == 'Both' and build_add_wind == 1")[['Max LMP', 'h2_price_per_kg', 'NPV [$Bil]', 'wind_mw', 'batt_mw', 'pem_mw', 'turb_mw']]
plot_results(results, "Variable Wind Design for DA+RT Market")
